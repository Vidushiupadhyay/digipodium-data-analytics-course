# %% [markdown]
# ## World Statistics dataset from World Bank

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                      NaN
# 1  Afghanistan          AFG  1961                                      NaN
# 2  Afghanistan          AFG  1962                                      NaN
# 3  Afghanistan          AFG  1963                                      NaN
# 4  Afghanistan          AFG  1964                                      NaN
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df.tail()
# Out:
#       Country Name Country Code  year  \
# 16099     Zimbabwe          ZWE  2016
# 16100     Zimbabwe          ZWE  2017
# 16101     Zimbabwe          ZWE  2018
# 16102     Zimbabwe          ZWE  2019
# 16103     Zimbabwe          ZWE  2020
#
#        Access to electricity (% of population)  \
# 16099                                39.923992
# 16100                                40.482048
# 16101                                41.041584
# 16102                                      NaN
# 16103                                      NaN
#
#        Access to electricity, rural (% of rural population)  \
# 16099                                          18.278332
# 16100                                          19.152600
# 16101                                          19.997750
# 16102                                                NaN
# 16103                                                NaN
#
#        Agricultural irrigated land (% of total agricultural land)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16104 entries, 0 to 16103
# Data columns (total 55 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Country Name                                                                                16104 non-null  object
#  1   Country Code                                                                                16104 non-null  object
#  2   year                                                                                        16104 non-null  int64
#  3   Access to electricity (% of population)                                                     6174 non-null   float64
#  4   Access to electricity, rural (% of rural population)                                        5959 non-null   float64
# ...

# %%
df
# Out:
#       Country Name Country Code  year  \
# 0      Afghanistan          AFG  1960
# 1      Afghanistan          AFG  1961
# 2      Afghanistan          AFG  1962
# 3      Afghanistan          AFG  1963
# 4      Afghanistan          AFG  1964
# ...            ...          ...   ...
# 16099     Zimbabwe          ZWE  2016
# 16100     Zimbabwe          ZWE  2017
# 16101     Zimbabwe          ZWE  2018
# 16102     Zimbabwe          ZWE  2019
# 16103     Zimbabwe          ZWE  2020
#
#        Access to electricity (% of population)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 16099                                39.923992
# 16100                                40.482048
# 16101                                41.041584
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                                                                      0
# Country Code                                                                                      0
# year                                                                                              0
# Access to electricity (% of population)                                                        9930
# Access to electricity, rural (% of rural population)                                          10145
# Agricultural irrigated land (% of total agricultural land)                                    15248
# Agricultural land (% of land area)                                                             3049
# Agricultural land (sq. km)                                                                     2872
# Agricultural machinery, tractors                                                               8321
# ...

# %% [markdown]
# Data Cleaning

# %%
ate = df['Access to electricity (% of population)'].astype('float').mean()
df['Access to electricity (% of population)'].replace(np.nan, ate , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
ater = df['Access to electricity, rural (% of rural population)'].astype('float').mean()
df['Access to electricity, rural (% of rural population)'].replace(np.nan, ater , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
ail = df['Agricultural irrigated land (% of total agricultural land)'].astype('float').mean()
df['Agricultural irrigated land (% of total agricultural land)'].replace(np.nan, ail , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
al = df['Agricultural land (% of land area)'].astype('float').mean()
df['Agricultural land (% of land area)'].replace(np.nan, al , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
alskm = df['Agricultural land (sq. km)'].astype('float').mean()
df['Agricultural land (sq. km)'].replace(np.nan, alskm , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
amt = df['Agricultural machinery, tractors'].astype('float').mean()
df['Agricultural machinery, tractors'].replace(np.nan, amt , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
amtskm = df['Agricultural machinery, tractors per 100 sq. km of arable land'].astype('float').mean()
df['Agricultural machinery, tractors per 100 sq. km of arable land'].replace(np.nan, amtskm , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
ame = df['Agricultural methane emissions (% of total)'].astype('float').mean()
df['Agricultural methane emissions (% of total)'].replace(np.nan, ame , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
ame2 = df['Agricultural methane emissions (thousand metric tons of CO2 equivalent)'].astype('float').mean()
df['Agricultural methane emissions (thousand metric tons of CO2 equivalent)'].replace(np.nan, ame2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
anoe = df['Agricultural nitrous oxide emissions (% of total)'].astype('float').mean()
df['Agricultural nitrous oxide emissions (% of total)'].replace(np.nan, anoe , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
anoe2 = df['Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)'].astype('float').mean()
df['Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)'].replace(np.nan, anoe2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
arme = df['Agricultural raw materials exports (% of merchandise exports)'].astype('float').mean()
df['Agricultural raw materials exports (% of merchandise exports)'].replace(np.nan, arme , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
armi = df['Agricultural raw materials imports (% of merchandise imports)'].astype('float').mean()
df['Agricultural raw materials imports (% of merchandise imports)'].replace(np.nan, armi , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
affv = df['Agriculture, forestry, and fishing, value added (% of GDP)'].astype('float').mean()
df['Agriculture, forestry, and fishing, value added (% of GDP)'].replace(np.nan, affv , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
affva = df['Agriculture, forestry, and fishing, value added (current US$)'].astype('float').mean()
df['Agriculture, forestry, and fishing, value added (current US$)'].replace(np.nan, affva , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
afwa = df['Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)'].astype('float').mean()
df['Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)'].replace(np.nan, afwa , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
arable = df['Arable land (% of land area)'].astype('float').mean()
df['Arable land (% of land area)'].replace(np.nan, arable , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
arable_l = df['Arable land (hectares per person)'].astype('float').mean()
df['Arable land (hectares per person)'].replace(np.nan, arable_l , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
arable_h = df['Arable land (hectares)'].astype('float').mean()
df['Arable land (hectares)'].replace(np.nan, arable_h , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
apd = df['Average precipitation in depth (mm per year)'].astype('float').mean()
df['Average precipitation in depth (mm per year)'].replace(np.nan, apd , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
brc = df['Birth rate, crude (per 1,000 people)'].astype('float').mean()
df['Birth rate, crude (per 1,000 people)'].replace(np.nan, brc , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
cp = df['Cereal production (metric tons)'].astype('float').mean()
df['Cereal production (metric tons)'].replace(np.nan, cp , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
cy = df['Cereal yield (kg per hectare)'].astype('float').mean()
df['Cereal yield (kg per hectare)'].replace(np.nan, cy , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
cpia = df['CPIA gender equality rating (1=low to 6=high)'].astype('float').mean()
df['CPIA gender equality rating (1=low to 6=high)'].replace(np.nan, cpia , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
cpi = df['Crop production index (2004-2006 = 100)'].astype('float').mean()
df['Crop production index (2004-2006 = 100)'].replace(np.nan, cpi , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
drc = df['Death rate, crude (per 1,000 people)'].astype('float').mean()
df['Death rate, crude (per 1,000 people)'].replace(np.nan, drc , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
eia = df['Employment in agriculture (% of total employment) (modeled ILO estimate)'].astype('float').mean()
df['Employment in agriculture (% of total employment) (modeled ILO estimate)'].replace(np.nan, eia , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
eiaf = df['Employment in agriculture, female (% of female employment) (modeled ILO estimate)'].astype('float').mean()
df['Employment in agriculture, female (% of female employment) (modeled ILO estimate)'].replace(np.nan, eiaf , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
eiam = df['Employment in agriculture, male (% of male employment) (modeled ILO estimate)'].astype('float').mean()
df['Employment in agriculture, male (% of male employment) (modeled ILO estimate)'].replace(np.nan, eiam , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
fc = df['Fertilizer consumption (% of fertilizer production)'].astype('float').mean()
df['Fertilizer consumption (% of fertilizer production)'].replace(np.nan, fc , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
fc2 = df['Fertilizer consumption (kilograms per hectare of arable land)'].astype('float').mean()
df['Fertilizer consumption (kilograms per hectare of arable land)'].replace(np.nan, fc2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
fpi = df['Food production index (2004-2006 = 100)'].astype('float').mean()
df['Food production index (2004-2006 = 100)'].replace(np.nan, fpi , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
fa = df['Forest area (% of land area)'].astype('float').mean()
df['Forest area (% of land area)'].replace(np.nan, fa , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
faskm = df['Forest area (sq. km)'].astype('float').mean()
df['Forest area (sq. km)'].replace(np.nan, faskm , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
gdp = df['GDP per capita (current US$)'].astype('float').mean()
df['GDP per capita (current US$)'].replace(np.nan, gdp , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
la = df['Land area (sq. km)'].astype('float').mean()
df['Land area (sq. km)'].replace(np.nan, la , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
lucp = df['Land under cereal production (hectares)'].astype('float').mean()
df['Land under cereal production (hectares)'].replace(np.nan, lucp , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
lrat = df['Literacy rate, adult total (% of people ages 15 and above)'].astype('float').mean()
df['Literacy rate, adult total (% of people ages 15 and above)'].replace(np.nan, lrat , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
lpi2 = df['Livestock production index (2004-2006 = 100)'].astype('float').mean()
df['Livestock production index (2004-2006 = 100)'].replace(np.nan, lpi2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
mr = df['Mineral rents (% of GDP)'].astype('float').mean()
df['Mineral rents (% of GDP)'].replace(np.nan, mr , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
mri = df['Mortality rate, infant (per 1,000 live births)'].astype('float').mean()
df['Mortality rate, infant (per 1,000 live births)'].replace(np.nan, mri , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
nm = df['Net migration'].astype('float').mean()
df['Net migration'].replace(np.nan, nm , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
pcl = df['Permanent cropland (% of land area)'].astype('float').mean()
df['Permanent cropland (% of land area)'].replace(np.nan, pcl , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
pt = df['Population, total'].astype('float').mean()
df['Population, total'].replace(np.nan, pt , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rla = df['Rural land area (sq. km)'].astype('float').mean()
df['Rural land area (sq. km)'].replace(np.nan, rla , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rural_land = df['Rural land area where elevation is below 5 meters (% of total land area)'].astype('float').mean()
df['Rural land area where elevation is below 5 meters (% of total land area)'].replace(np.nan, rural_land , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rural_land_2 = df['Rural land area where elevation is below 5 meters (sq. km)'].astype('float').mean()
df['Rural land area where elevation is below 5 meters (sq. km)'].replace(np.nan, rural_land_2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rp = df['Rural population'].astype('float').mean()
df['Rural population'].replace(np.nan, rp , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rp2 = df['Rural population (% of total population)'].astype('float').mean()
df['Rural population (% of total population)'].replace(np.nan, rp2 , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rpg = df['Rural population growth (annual %)'].astype('float').mean()
df['Rural population growth (annual %)'].replace(np.nan, rpg , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
rpl = df['Rural population living in areas where elevation is below 5 meters (% of total population)'].astype('float').mean()
df['Rural population living in areas where elevation is below 5 meters (% of total population)'].replace(np.nan, rpl , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
sa = df['Surface area (sq. km)'].astype('float').mean()
df['Surface area (sq. km)'].replace(np.nan, sa , inplace=True)
df.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                79.955627
# 1  Afghanistan          AFG  1961                                79.955627
# 2  Afghanistan          AFG  1962                                79.955627
# 3  Afghanistan          AFG  1963                                79.955627
# 4  Afghanistan          AFG  1964                                79.955627
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          75.035009
# 1                                          75.035009
# 2                                          75.035009
# 3                                          75.035009
# 4                                          75.035009
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                          10.075554
# 1                                          10.075554
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                                                                  0
# Country Code                                                                                  0
# year                                                                                          0
# Access to electricity (% of population)                                                       0
# Access to electricity, rural (% of rural population)                                          0
# Agricultural irrigated land (% of total agricultural land)                                    0
# Agricultural land (% of land area)                                                            0
# Agricultural land (sq. km)                                                                    0
# Agricultural machinery, tractors                                                              0
# Agricultural machinery, tractors per 100 sq. km of arable land                                0
# ...

# %% [markdown]
# Data Visualisation

# %%
df['Access to electricity (% of population)'].value_counts()
# Out:
# 79.955627     9930
# 100.000000    2373
# 99.900000       18
# 99.000000       16
# 99.800000       15
#               ...
# 20.391159        1
# 22.690285        1
# 23.827271        1
# 24.971313        1
# 41.041584        1
# Name: Access to electricity (% of population), Length: 3455, dtype: int64

# %%
px.box(df, 'Access to electricity (% of population)')

# %%
dfgb = df.groupby('Country Code' , as_index= False)['Access to electricity (% of population)'].value_counts()
dfgb
# Out:
#      Country Code  Access to electricity (% of population)  count
# 0             ABW                                79.955627     42
# 1             ABW                               100.000000     17
# 2             ABW                                93.356292      1
# 3             ABW                                91.660398      1
# 4             AFG                                79.955627     47
# ...           ...                                      ...    ...
# 4155          ZWE                                40.482048      1
# 4156          ZWE                                41.041584      1
# 4157          ZWE                                43.369082      1
# 4158          ZWE                                44.000000      1
# 4159          ZWE                                28.100000      1
#
# [4160 rows x 3 columns]

# %%
px.histogram(df , x='Country Code' , y='Access to electricity (% of population)' )

# %%
cn=df.year.value_counts().reset_index()
cn.columns = ['year','Agricultural methane emissions (% of total)']
cn
# Out:
#     year  Agricultural methane emissions (% of total)
# 0   1960                                          264
# 1   1991                                          264
# 2   1993                                          264
# 3   1994                                          264
# 4   1995                                          264
# ..   ...                                          ...
# 56  1985                                          264
# 57  1986                                          264
# 58  1987                                          264
# 59  1988                                          264
# 60  2020                                          264
#
# [61 rows x 2 columns]

# %%
cn = cn.head(61)
px.pie(cn, 'year','Agricultural methane emissions (% of total)')

# %%
cn2=df.year.value_counts().reset_index()
cn2.columns = ['year','Agricultural raw materials exports (% of merchandise exports)']
cn2
# Out:
#     year  Agricultural raw materials exports (% of merchandise exports)
# 0   1960                                                264
# 1   1991                                                264
# 2   1993                                                264
# 3   1994                                                264
# 4   1995                                                264
# ..   ...                                                ...
# 56  1985                                                264
# 57  1986                                                264
# 58  1987                                                264
# 59  1988                                                264
# 60  2020                                                264
#
# [61 rows x 2 columns]

# %%
cn2 = cn2.head(60)
px.bar(cn2 , 'year','Agricultural raw materials exports (% of merchandise exports)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\HP\Documents\data\Mini_ project\abc.ipynb Cell 71 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/data/Mini_%20project/abc.ipynb#Y140sZmlsZQ%3D%3D?line=0'>1</a> cn2 = cn2.head(60)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/data/Mini_%20project/abc.ipynb#Y140sZmlsZQ%3D%3D?line=1'>2</a> px.bar(cn2 , 'year','Agricultural raw materials exports (% of merchandise exports)')
#
# ...
